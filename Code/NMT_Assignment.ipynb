# %% [markdown]
# Neural Machine Translation:
# ===
# The aim of this notebook is to illustrate how to create and train a neural machine translation pipeline. Machine Translation is the task of automatically converting source text in one language to text in another language. In this notebook, we will try to build End-2-End pipeline to translate setences from English to Hindi
#
# The notebook has been divided into two parts: In part I, I have discussed step-by-step process of building an end-2-end pipeline from scratch to translate sentences from English to Hindi. In part II, Instead of building a pipeline from scratch, I have shown the usage of AutoML framework to create a Neural Machine Translation System.

# %% [markdown]
# Part I:
# ---
# The step-by-step process of building an End-2-End pipeline from scratch is divided into following parts:
#
#   * Pre-process our data (Data Preprocessing)
#     * Convert to lowercase
#     * Remove all the special characters
#     * Remove all the numbers from text
#   * Tokenization
#     * Sentence tokenization
#     * Remove extra spaces (leading and trailing)
#     * START and END tokens to sentences
#   * Model Architecture
#     * Choose an sequence model
#     * Architecture and layers explanation
#     * Attention and explanation
#   * Model training and Hyperparameters optimization
#     * Epochs, Batch Size, Layers
#     * Sample sentence prediction
#   * Evaluation metric: Calculate the BLEU score for the translation.

# %% [markdown]
# **Note: if you are running this notebook in Google Colaboratory, you have to download the dataset**

# %% [markdown]
# ### Data Download:

# %%
# !wget --header="Host: doc-08-a0-docs.googleusercontent.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://mail.google.com/mail/u/0/" --header="Cookie: AUTH_h2usbqe61t3p2javmc9f8vev3k7aj2re=09663297046543970124|1590855225000|vnbtokaapd9nf3iroaoqmb4dpinng0fa; NID=202=LrP4uDlw-tpJIrOsSSVGjEUAYFBvMgE7pYsHllDi2RvAiohnhILxLsaostbt-xc33InPBNV05z_jAtAw4Km239HIJCcIFMoWS8Yh1FmMW-xpd8qowQuNbmhfho6LYG4h7_JheMnumByEDYwFL3O_tCzX30sFKeeVfNE_XxYUTwM" --header="Connection: keep-alive" "https://doc-08-a0-docs.googleusercontent.com/docs/securesc/035r11cge54f61vkg6q5351jddbf1r9g/i9m3eas59qd0vc9tku6hdm61d6k9a150/1590855225000/09367493494736841528/09663297046543970124/15yNTXYb65oz43nn9PIu6kyp792rr_yZ5?e=download&authuser=0" -c -O 'Hi-En-Parallel_Corpus.xlsx'
# Out:
# --2020-05-30 16:16:07--  https://doc-08-a0-docs.googleusercontent.com/docs/securesc/035r11cge54f61vkg6q5351jddbf1r9g/i9m3eas59qd0vc9tku6hdm61d6k9a150/1590855225000/09367493494736841528/09663297046543970124/15yNTXYb65oz43nn9PIu6kyp792rr_yZ5?e=download&authuser=0
# Resolving doc-08-a0-docs.googleusercontent.com (doc-08-a0-docs.googleusercontent.com)... 64.233.189.132, 2404:6800:4008:c07::84
# Connecting to doc-08-a0-docs.googleusercontent.com (doc-08-a0-docs.googleusercontent.com)|64.233.189.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘Hi-En-Parallel_Corpus.xlsx’
#
# Hi-En-Parallel_Corp     [ <=>                ]  16.83M   107MB/s    in 0.2s
#
# 2020-05-30 16:16:08 (107 MB/s) - ‘Hi-En-Parallel_Corpus.xlsx’ saved [17653110]

# %%
# check if file is downloaded successfully
# !ls
# Out:
# Hi-En-Parallel_Corpus.xlsx  sample_data

# %% [markdown]
# ### Read the file:

# %%
# import libraries for processing
import pandas as pd
import numpy as np
import string
from string import digits
import matplotlib.pyplot as plt
# %matplotlib inline
import re
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.layers import Input, LSTM, Embedding, Dense
from keras.models import Model

# %%
lines = pd.read_excel('Hi-En-Parallel_Corpus.xlsx')
# a look to data
lines.head()

# %% [markdown]
# ### Data Preprocessing:
#
# As we can see, our text consist of both capital and small words (e.g. "The", "the"), **numbers** (e.g. 0.001, 200), **punctuation** (e.g. ",", ".", ";", "--"), etc.
#
# These observations, suggest that before we start building the model, we need to perfrom data cleaning and preparation.
#
# Firstly, we will **lowercase** the entire text, this way we won't have to worry about **case sensitivity** of text.
#
# After that, we will **remove special character** (e.g. "--", ".") using regex since, they don't add any meaning to the text. A RegEx or **Regular Expression is a sequence of characters that define a search pattern**. We will be using RegEx module python built-in package re and filter only useful text.
#
# Similarly, we will remove numeric characters from our text.

# %%
# before preprocessing we make sure our data is in string format 
lines.english_sentence=lines.english_sentence.astype(str)
lines.hindi_sentence=lines.hindi_sentence.astype(str)
# a look to data to observe changes
lines.head()

# %%
# Lowercase all characters
lines.english_sentence=lines.english_sentence.apply(lambda x: x.lower())
lines.hindi_sentence=lines.hindi_sentence.apply(lambda x: x.lower())
# a look to data to observe changes
lines.head()

# %%
exclude = set(string.punctuation) # Set of all special characters
# Remove all the special characters
lines.english_sentence=lines.english_sentence.apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
lines.hindi_sentence=lines.hindi_sentence.apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
# a look to data to observe changes
lines.tail()

# %%
# Remove all numbers from text
remove_digits = str.maketrans('', '', digits)
lines.english_sentence=lines.english_sentence.apply(lambda x: x.translate(remove_digits))
lines.hindi_sentence = lines.hindi_sentence.apply(lambda x: re.sub("[२३०८१५७९४६]", "", x))
# a look to data to observe changes
lines.head()

# %% [markdown]
# ### Tokenization:
#
# Once, we have pre-process our text, we can further focus on **splitting our text into tokens like list of sentences or list of words**. We can think of token as parts like a word is a token in a sentence, and sentence is a token in a paragraph. The former one known as sentence tokenization and later one word tokenization. We will now try to tokenize the text

# %%
# Sentence tokenization
lines.english_sentence=lines.english_sentence.apply(lambda x: x.strip())
lines.hindi_sentence=lines.hindi_sentence.apply(lambda x: x.strip())
# a look to data to observe changes
lines.tail()

# %%
# Remove extra spaces
lines.english_sentence=lines.english_sentence.apply(lambda x: x.lstrip())
lines.hindi_sentence=lines.hindi_sentence.apply(lambda x: x.lstrip())
lines.english_sentence=lines.english_sentence.apply(lambda x: x.rstrip())
lines.hindi_sentence=lines.hindi_sentence.apply(lambda x: x.rstrip())
# a look to data to observe changes
lines.tail()

# %%
# Add start and end tokens to target sequences
lines.hindi_sentence = lines.hindi_sentence.apply(lambda x : 'START_ '+ x + ' _END')

# %%
lines = shuffle(lines)
lines.sample(10)

# %% [markdown]
# Dataset consist of observations with maximum sentence length of . Therefore, we will perform experiment on small subset of dataset with only 33725 observations

# %%
# Randomly sample 33725 observations
lines = lines.sample(n=33725)
lines.shape

# %% [markdown]
# We will define the problem such that the input and output sequences are of same length and pad
# the output sequences with "0" values as needed.

# %%
# Vocabulary of English
all_eng_words=set()
for eng in lines.english_sentence:
    for word in eng.split():
        if word not in all_eng_words:
            all_eng_words.add(word)

# Vocabulary of French 
all_hindi_words=set()
for mar in lines.hindi_sentence:
    for word in mar.split():
        if word not in all_hindi_words:
            all_hindi_words.add(word)

# %% [markdown]
# We then try to identify the length of the largest sentence by iterting through all the available Input Sequences

# %%
# Max Length of source sequence
lenght_list=[]
for l in lines.english_sentence:
    lenght_list.append(len(l.split(' ')))
max_length_src = np.max(lenght_list)
max_length_src

# %%
# Max Length of target sequence
lenght_list=[]
for l in lines.hindi_sentence:
    lenght_list.append(len(l.split(' ')))
max_length_tar = np.max(lenght_list)
max_length_tar

# %%
input_words = sorted(list(all_eng_words))
target_words = sorted(list(all_hindi_words))
num_encoder_tokens = len(all_eng_words)
num_decoder_tokens = len(all_hindi_words)
num_encoder_tokens, num_decoder_tokens

# %%
num_decoder_tokens += 1 # For zero padding
num_decoder_tokens

# %% [markdown]
# Now we begin to segregate the Input Sequences by collecting all the encoded words following upto the last word as the input to the model and the last encoded word as the target label and store both of them in separate lists.

# %%
input_token_index = dict([(word, i+1) for i, word in enumerate(input_words)])
target_token_index = dict([(word, i+1) for i, word in enumerate(target_words)])

# %%
reverse_input_char_index = dict((i, word) for word, i in input_token_index.items())
reverse_target_char_index = dict((i, word) for word, i in target_token_index.items())

# %%
# Train - Test Split
X, y = lines.english_sentence, lines.hindi_sentence
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)
X_train.shape, X_test.shape

# %% [markdown]
# #### Save the train and test dataframes for reproducing the results later, as they are shuffled.

# %%
X_train.to_pickle('X_train.pkl')
X_test.to_pickle('X_test.pkl')

# %%
def generate_batch(X = X_train, y = y_train, batch_size = 128):
    ''' Generate a batch of data '''
    while True:
        for j in range(0, len(X), batch_size):
            encoder_input_data = np.zeros((batch_size, max_length_src),dtype='float32')
            decoder_input_data = np.zeros((batch_size, max_length_tar),dtype='float32')
            decoder_target_data = np.zeros((batch_size, max_length_tar, num_decoder_tokens),dtype='float32')
            for i, (input_text, target_text) in enumerate(zip(X[j:j+batch_size], y[j:j+batch_size])):
                for t, word in enumerate(input_text.split()):
                    encoder_input_data[i, t] = input_token_index[word] # encoder input seq
                for t, word in enumerate(target_text.split()):
                    if t<len(target_text.split())-1:
                        decoder_input_data[i, t] = target_token_index[word] # decoder input seq
                    if t>0:
                        # decoder target sequence (one hot encoded)
                        # does not include the START_ token
                        # Offset by one timestep
                        decoder_target_data[i, t - 1, target_token_index[word]] = 1.
            yield([encoder_input_data, decoder_input_data], decoder_target_data)

# %% [markdown]
# ### Model Architecture:
#
# In this part, we will study how to define a neural network for machine translation, the neural network for Neural Machine Translation uses a Sequential-2-Sequential model. We can think of the seq-2-seq model as being comprised of two key parts: the encoder and the decoder. We can develop a simple encoder-decoder model in keras by taking the output from an encoder LSTM model, repeating it n times for the number of timesteps in the output sequence, then using a decoder to predict the output sequence.

# %%
latent_dim = 50 # number of units in neural network

# %%
# Encoder
encoder_inputs = Input(shape=(None,))
enc_emb =  Embedding(num_encoder_tokens, latent_dim, mask_zero = True)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(enc_emb)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# %% [markdown]
# ### Embedding layer:
#
# A word-embedding layer is used to represent words input to the encoder. This is a distributed representation where each word is mapped to a fixed-vector of continous values. Advantage of using this layer is that different words with similar meaning will have a similar representation.
#
# This distributed representation of similar meaning is often learned while fitting the model on the training data. The embedding size defines the length of the vectors used to represent words in this case max length of sentence in training dataset.

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))
dec_emb_layer = Embedding(num_decoder_tokens, latent_dim, mask_zero = True)
dec_emb = dec_emb_layer(decoder_inputs)
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(dec_emb,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# ### Recurrent neural network:
#
# There are three types of recurrent neural network cells that are commonly used:
# * Simple RNN
# * Long Short-Term Memory or LSTM
# * Gated Recurrent Unit or GRU
#
# The LSTM was developed to address the vanishing gradient problem of the Simple RNN that limited the training of deep RNNs. By using LSTM type RNN we will create a seq-2-seq model for neural machine translation

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

# %% [markdown]
# We will train the model with **categorical cross entropy loss** using **rmsprop adaptive optimization algorithm** for **3 epochs** since, one epoch take **4 hours on Tesla P100 GPU** with **4 batch size** so that our GPU able to store them in memory

# %%
train_samples = len(X_train)
val_samples = len(X_test)
batch_size = 4
epochs = 4

# %%
model.fit_generator(generator = generate_batch(X_train, y_train, batch_size = batch_size),
                    steps_per_epoch = train_samples//batch_size,
                    epochs=epochs,
                    validation_data = generate_batch(X_test, y_test, batch_size = batch_size),
                    validation_steps =
                    val_samples//batch_size)

# %% [markdown]
# ### Save the weights

# %%
model.save_weights('nmt_weights.h5')

# %% [markdown]
# ### Load the weights, if you close the application

# %%
model.load_weights('nmt_weights.h5')

# %% [markdown]
# ### Inference Setup

# %%
# Encode the input sequence to get the "thought vectors"
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

dec_emb2= dec_emb_layer(decoder_inputs) # Get the embeddings of the decoder sequence

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]
decoder_outputs2 = decoder_dense(decoder_outputs2) # A dense softmax layer to generate prob dist. over the target vocabulary

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs2] + decoder_states2)

# %% [markdown]
# ### Decode sample sequeces

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0] = target_token_index['START_']

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += ' '+sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '_END' or
           len(decoded_sentence) > 50):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %% [markdown]
# ### Sample Sentence Prediction

# %%
train_gen = generate_batch(X_train, y_train, batch_size = 1)
k=-1

# %% [markdown]
# ### Evaluting Prediction

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

actual, predicted = list(), list()
for k, x in enumerate(train_gen):
  k+=1
  (input_seq, actual_output), _ = x
  decoded_sentence = decode_sequence(input_seq)
  print('Input English sentence:', X_train[k:k+1].values[0])
  print('Actual Marathi Translation:', y_train[k:k+1].values[0][6:-4])
  print('Predicted Marathi Translation:', decoded_sentence[:-4])
  #print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
  actual.append([y_train[k:k+1].values[0][6:-4]])
  predicted.append(decoded_sentence[:-4])
  if k>10:
    	# calculate BLEU score
      print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
      print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
      print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
      print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))
      break
# Out:
# Input English sentence: encouraged by thishitler mounted attack on sudetenland which was the western part of czechoslovakia where ethnic german population was highwas mounted attack on it
# Actual Marathi Translation:  इस बात से उत्साहित होकर हिटलर ने सदतेनलैंड जो की चेकोस्लोवाकिया का पश्चिमी हिस्सा है और जहाँ जर्मन भाषा बोलने वालों की ज्यादा तादात थी वहां पर हमला बोल दिया ।
# Predicted Marathi Translation:  यह एक है कि वे एक और एक एक है
# Input English sentence: there is a sequentialactivation and repression of genes through the three phases of life development reproduction and senescence
# Actual Marathi Translation:  जीवन के तीनों कालोंविकास प्रजनन और जराजन्यताके दौरान सक्रिय सक्रियता और निग्रह होता है
# Predicted Marathi Translation:  लिए यह है कि वे अपने लिए यह है कि वह अपने लिए भी
# Input English sentence: he had lost his wife and two children of the three surviving ones the eldest daughter lived with her husband outside bengal the eldest son had been sent to the united states the previous year for training in agricultural science and the third daughter mira had been married a few months earlier
# Actual Marathi Translation:  उन्होंने अपनी पत्नी और दो बच्चों को खोया थाजीवित तीन संतानों में से सबसे बड़ी बेटी अपने पति के साथ बंगाल के बाहर रह रही थी सबसे बड़ा बेटा पिछले साल ही संयुक्त राष्ट्र अमेरिका में कृषि विज्ञान में प्रशिक्षण के लिए भेजा गया थातीसरी बेटी मीरा कुछ महीने पहले ही ब्याही गई थी
# Predicted Marathi Translation:  लेकिन यह एक एक है कि
# Input English sentence: the centre may have “ barked ” jayalalitha into submission but her onslaught shows that its flanks are not guarded with constitutional power
# Actual Marathi Translation:  केंद्र ने अपनी घुड़ेकी से जयललिता को पीछै हटने पर भले मजबूर कर दिया हो लेकिन उनके हमलं से जाहिर है कि इस संदर्भ में केंद्र को कोई स्पष्ट संवैधानिक अधिकार हासिल नहीं है
# Predicted Marathi Translation:  लेकिन यह एक है कि वे एक और
# Input English sentence: both kinds of things are equal in their eyes since they cannot raise themselves to the methods of a strictly scientific deduction
# Actual Marathi Translation:  उनकी दृष्टि में दोनों प्रकार की वस्तुएं समान हैं इसलिए कि वे स्वयं को शुद्ध वैज्ञानिक निगमन की पद्धतियों तक उठाने में असमर्थ हैं
# Predicted Marathi Translation:  और यह एक और एक है और यह एक है कि वे अपने लिए य
# Input English sentence: a good practice is to graze flocks in a light soil in the morning and on fallows of heavier soils in the afternoon
# Actual Marathi Translation:  यह अच्छा रहता है यदि रेवड़ को प्रात काल हल्की भूमि पर तथा दोपहर बाद अपेक्षतया भारी परती भूमि पर चराया जाये
# Predicted Marathi Translation:  और यह एक और एक और एक और लिए एक लिए
# Input English sentence: bal thackeray refuted the allegations stating “”amitabh bachchan is an openminded person he has great love for maharashtra and this is evident on many occasions
# Actual Marathi Translation:  बाल ठाकरे ने आरोपों का खंडन करते हुए कहा कि अमिताभ बच्चन एक खुले दिमाग वाला व्यक्ति है और महाराष्ट्र के लिए उनके मन में विशेष प्रेम है जिन्हें कई अवसरों पर देखा जा चुका है।
# Predicted Marathi Translation:  तो आप के लिए एक नहीं है
# Input English sentence: this is not desirable as it results in a great deal of waste of plant nutrients from the manure through the action of wind and rain and is also insanitary
# Actual Marathi Translation:  इस तरीके से वर्षा और हवा के कारण खाद में विद्यमान पऋधों के लिए पुषऋऊण्श्छ्ष्टिकारक ततऋऊण्श्छ्ष्व नषऋऊण्श्छ्ष्ट हो जाते हैंइसके ढअतिरिकऋऊण्श्छ्ष्त यह तरीका असऋऊण्श्छ्ष्वासऋऊण्श्छ्ष्थऋऊण्श्छ्ष्यकर भी है
# Predicted Marathi Translation:  यह है कि वे अपने लिए यह है कि वह अपने लिए भी नही
# Input English sentence: inevitably many of the champions who have entered the field of battle have little to do with scholarship or the love of a language for its own sake
# Actual Marathi Translation:  इसका यह नतीजा हुआ है और जो लाजिमी था कि बहुतसे ऐसे सूरमा मैदान में उतर आये हैं जिनका पढ़ाईलिखाई से बहुत कम वास्ता है और भाषा से उसकी खातिर ही सही उनका कोई लगाव नहीं है
# Predicted Marathi Translation:  और एक और एक
# Input English sentence: when i did the experiment when i did the test
# Actual Marathi Translation:  जब मैंने दो महीने बाद यह प्रयोग किया
# Predicted Marathi Translation:  इस तरह के लिए यह एक है कि वे अपने और लिए यह एक ह
# Input English sentence: that makes a good cartoon
# Actual Marathi Translation:  जिसका कार्टून अच्छा बनता है
# Predicted Marathi Translation:  एक और एक एक है
# BLEU-1: 0.031585
# BLEU-2: 0.021154
# BLEU-3: 0.016254
# BLEU-4: 0.010701

# %% [markdown]
# Part 2: Using AutoML framework - Uber Ludwig
# ---
# Ludwig is a toolbox built on top of TensorFlow that allows to train and test deep learning models without the need to write code.
#
# All you need to provide is a CSV file containing your data, a list of columns to use as inputs, and a list of columns to use as outputs, in the form of yaml file; Ludwig will do the rest. Simple commands can be used to train models both locally and in a distributed way, and to use them to predict on new data.

# %% [markdown]
# ### Clone the repository

# %%
# !git clone https://github.com/uber/ludwig.git
# Out:
# Cloning into 'ludwig'...
# remote: Enumerating objects: 166, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 9530 (delta 97), reused 93 (delta 49), pack-reused 9364
# Receiving objects: 100% (9530/9530), 13.39 MiB | 7.57 MiB/s, done.
# Resolving deltas: 100% (6801/6801), done.

# %% [markdown]
# ### Change requirements.txt to train on GPU

# %%
# %%writefile ludwig/requirements.txt
# Cython>=0.25
# h5py>=2.6
# numpy>=1.15
# pandas>=0.19
# scipy>=0.18
# tabulate>=0.7
# scikit-learn
# tqdm
# tensorflow-gpu==1.15.2
# PyYAML>=3.12
# absl-py
# Out:
# Overwriting ludwig/requirements.txt

# %% [markdown]
# ### Install the library using bash commands

# %%
# %%bash
# cd ludwig
# pip install -r requirements.txt
# python setup.py install
# Out:
# Requirement already satisfied: Cython>=0.25 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (0.29.18)
# Requirement already satisfied: h5py>=2.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (2.10.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (1.18.4)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (1.0.3)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (1.4.1)
# Requirement already satisfied: tabulate>=0.7 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (0.8.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 7)) (0.22.2.post1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 8)) (4.41.1)
# Collecting tensorflow-gpu==1.15.2
#   Downloading https://files.pythonhosted.org/packages/32/ca/58e40e5077fa2a92004f398d705a288e958434f123938f4ce75ffe25b64b/tensorflow_gpu-1.15.2-cp36-cp36m-manylinux2010_x86_64.whl (411.0MB)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 10)) (3.13)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py>=2.6->-r requirements.txt (line 2)) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->-r requirements.txt (line 4)) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->-r requirements.txt (line 4)) (2018.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->-r requirements.txt (line 7)) (0.15.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (1.29.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (1.12.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (0.34.2)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (1.0.8)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (1.1.2)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (3.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (3.2.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (46.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (3.2.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow-gpu==1.15.2->-r requirements.txt (line 9)) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py): started
#   Building wheel for gast (setup.py): finished with status 'done'
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=2d3c1d468958c5d75489d12cdfec093e5e00d49c7e78e071d7e85d3701b8da0c
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, gast, tensorflow-gpu
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
# Successfully installed gast-0.2.2 tensorboard-1.15.0 tensorflow-estimator-1.15.1 tensorflow-gpu-1.15.2
# running install
# running bdist_egg
# running egg_info
# creating ludwig.egg-info
# writing ludwig.egg-info/PKG-INFO
# writing dependency_links to ludwig.egg-info/dependency_links.txt
# writing entry points to ludwig.egg-info/entry_points.txt
# writing requirements to ludwig.egg-info/requires.txt
# writing top-level names to ludwig.egg-info/top_level.txt
# writing manifest file 'ludwig.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'ludwig.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/ludwig
# copying ludwig/experiment.py -> build/lib/ludwig
# copying ludwig/globals.py -> build/lib/ludwig
# copying ludwig/train.py -> build/lib/ludwig
# copying ludwig/neuropod_export.py -> build/lib/ludwig
# copying ludwig/cli.py -> build/lib/ludwig
# copying ludwig/contrib.py -> build/lib/ludwig
# copying ludwig/collect.py -> build/lib/ludwig
# copying ludwig/__init__.py -> build/lib/ludwig
# copying ludwig/serve.py -> build/lib/ludwig
# copying ludwig/api.py -> build/lib/ludwig
# copying ludwig/predict.py -> build/lib/ludwig
# copying ludwig/test_performance.py -> build/lib/ludwig
# copying ludwig/constants.py -> build/lib/ludwig
# copying ludwig/visualize.py -> build/lib/ludwig
# creating build/lib/ludwig/contribs
# copying ludwig/contribs/comet.py -> build/lib/ludwig/contribs
# copying ludwig/contribs/__init__.py -> build/lib/ludwig/contribs
# copying ludwig/contribs/wandb.py -> build/lib/ludwig/contribs
# creating build/lib/ludwig/features
# copying ludwig/features/date_feature.py -> build/lib/ludwig/features
# copying ludwig/features/timeseries_feature.py -> build/lib/ludwig/features
# copying ludwig/features/category_feature.py -> build/lib/ludwig/features
# copying ludwig/features/text_feature.py -> build/lib/ludwig/features
# copying ludwig/features/bag_feature.py -> build/lib/ludwig/features
# copying ludwig/features/binary_feature.py -> build/lib/ludwig/features
# copying ludwig/features/vector_feature.py -> build/lib/ludwig/features
# copying ludwig/features/base_feature.py -> build/lib/ludwig/features
# copying ludwig/features/numerical_feature.py -> build/lib/ludwig/features
# copying ludwig/features/h3_feature.py -> build/lib/ludwig/features
# copying ludwig/features/__init__.py -> build/lib/ludwig/features
# copying ludwig/features/sequence_feature.py -> build/lib/ludwig/features
# copying ludwig/features/set_feature.py -> build/lib/ludwig/features
# copying ludwig/features/audio_feature.py -> build/lib/ludwig/features
# copying ludwig/features/feature_utils.py -> build/lib/ludwig/features
# copying ludwig/features/feature_registries.py -> build/lib/ludwig/features
# copying ludwig/features/image_feature.py -> build/lib/ludwig/features
# creating build/lib/ludwig/data
# copying ludwig/data/split_dataset.py -> build/lib/ludwig/data
# copying ludwig/data/preprocessing.py -> build/lib/ludwig/data
# copying ludwig/data/dataset_synthesyzer.py -> build/lib/ludwig/data
# copying ludwig/data/postprocessing.py -> build/lib/ludwig/data
# copying ludwig/data/dataset.py -> build/lib/ludwig/data
# copying ludwig/data/concatenate_datasets.py -> build/lib/ludwig/data
# copying ludwig/data/__init__.py -> build/lib/ludwig/data
# creating build/lib/ludwig/utils
# copying ludwig/utils/data_utils.py -> build/lib/ludwig/utils
# copying ludwig/utils/image_utils.py -> build/lib/ludwig/utils
# copying ludwig/utils/misc.py -> build/lib/ludwig/utils
# copying ludwig/utils/nlp_utils.py -> build/lib/ludwig/utils
# copying ludwig/utils/batcher.py -> build/lib/ludwig/utils
# copying ludwig/utils/html_utils.py -> build/lib/ludwig/utils
# copying ludwig/utils/defaults.py -> build/lib/ludwig/utils
# copying ludwig/utils/strings_utils.py -> build/lib/ludwig/utils
# copying ludwig/utils/h3_util.py -> build/lib/ludwig/utils
# copying ludwig/utils/algorithms_utils.py -> build/lib/ludwig/utils
# copying ludwig/utils/tf_utils.py -> build/lib/ludwig/utils
# copying ludwig/utils/visualization_utils.py -> build/lib/ludwig/utils
# copying ludwig/utils/print_utils.py -> build/lib/ludwig/utils
# copying ludwig/utils/audio_utils.py -> build/lib/ludwig/utils
# copying ludwig/utils/metrics_utils.py -> build/lib/ludwig/utils
# copying ludwig/utils/__init__.py -> build/lib/ludwig/utils
# copying ludwig/utils/math_utils.py -> build/lib/ludwig/utils
# copying ludwig/utils/time_utils.py -> build/lib/ludwig/utils
# creating build/lib/ludwig/models
# copying ludwig/models/model.py -> build/lib/ludwig/models
# copying ludwig/models/inputs.py -> build/lib/ludwig/models
# copying ludwig/models/__init__.py -> build/lib/ludwig/models
# copying ludwig/models/outputs.py -> build/lib/ludwig/models
# copying ludwig/models/combiners.py -> build/lib/ludwig/models
# creating build/lib/ludwig/models/modules
# copying ludwig/models/modules/sequence_decoders.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/reduction_modules.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/embedding_modules.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/measure_modules.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/fully_connected_modules.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/image_encoders.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/dense_encoders.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/loss_modules.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/sequence_encoders.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/initializer_modules.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/recurrent_modules.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/optimization_modules.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/h3_encoders.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/attention_modules.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/__init__.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/date_encoders.py -> build/lib/ludwig/models/modules
# copying ludwig/models/modules/convolutional_modules.py -> build/lib/ludwig/models/modules
# copying ludwig/NOTICE -> build/lib/ludwig
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/ludwig
# creating build/bdist.linux-x86_64/egg/ludwig/contribs
# copying build/lib/ludwig/contribs/comet.py -> build/bdist.linux-x86_64/egg/ludwig/contribs
# copying build/lib/ludwig/contribs/__init__.py -> build/bdist.linux-x86_64/egg/ludwig/contribs
# copying build/lib/ludwig/contribs/wandb.py -> build/bdist.linux-x86_64/egg/ludwig/contribs
# copying build/lib/ludwig/experiment.py -> build/bdist.linux-x86_64/egg/ludwig
# creating build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/date_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/timeseries_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/category_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/text_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/bag_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/binary_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/vector_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/base_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/numerical_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/h3_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/__init__.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/sequence_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/set_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/audio_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/feature_utils.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/feature_registries.py -> build/bdist.linux-x86_64/egg/ludwig/features
# copying build/lib/ludwig/features/image_feature.py -> build/bdist.linux-x86_64/egg/ludwig/features
# creating build/bdist.linux-x86_64/egg/ludwig/data
# copying build/lib/ludwig/data/split_dataset.py -> build/bdist.linux-x86_64/egg/ludwig/data
# copying build/lib/ludwig/data/preprocessing.py -> build/bdist.linux-x86_64/egg/ludwig/data
# copying build/lib/ludwig/data/dataset_synthesyzer.py -> build/bdist.linux-x86_64/egg/ludwig/data
# copying build/lib/ludwig/data/postprocessing.py -> build/bdist.linux-x86_64/egg/ludwig/data
# copying build/lib/ludwig/data/dataset.py -> build/bdist.linux-x86_64/egg/ludwig/data
# copying build/lib/ludwig/data/concatenate_datasets.py -> build/bdist.linux-x86_64/egg/ludwig/data
# copying build/lib/ludwig/data/__init__.py -> build/bdist.linux-x86_64/egg/ludwig/data
# copying build/lib/ludwig/globals.py -> build/bdist.linux-x86_64/egg/ludwig
# copying build/lib/ludwig/train.py -> build/bdist.linux-x86_64/egg/ludwig
# creating build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/data_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/image_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/misc.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/nlp_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/batcher.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/html_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/defaults.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/strings_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/h3_util.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/algorithms_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/tf_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/visualization_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/print_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/audio_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/metrics_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/__init__.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/math_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/utils/time_utils.py -> build/bdist.linux-x86_64/egg/ludwig/utils
# copying build/lib/ludwig/neuropod_export.py -> build/bdist.linux-x86_64/egg/ludwig
# copying build/lib/ludwig/cli.py -> build/bdist.linux-x86_64/egg/ludwig
# copying build/lib/ludwig/contrib.py -> build/bdist.linux-x86_64/egg/ludwig
# copying build/lib/ludwig/collect.py -> build/bdist.linux-x86_64/egg/ludwig
# copying build/lib/ludwig/__init__.py -> build/bdist.linux-x86_64/egg/ludwig
# copying build/lib/ludwig/NOTICE -> build/bdist.linux-x86_64/egg/ludwig
# copying build/lib/ludwig/serve.py -> build/bdist.linux-x86_64/egg/ludwig
# creating build/bdist.linux-x86_64/egg/ludwig/models
# copying build/lib/ludwig/models/model.py -> build/bdist.linux-x86_64/egg/ludwig/models
# creating build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/sequence_decoders.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/reduction_modules.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/embedding_modules.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/measure_modules.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/fully_connected_modules.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/image_encoders.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/dense_encoders.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/loss_modules.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/sequence_encoders.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/initializer_modules.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/recurrent_modules.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/optimization_modules.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/h3_encoders.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/attention_modules.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/__init__.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/date_encoders.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/modules/convolutional_modules.py -> build/bdist.linux-x86_64/egg/ludwig/models/modules
# copying build/lib/ludwig/models/inputs.py -> build/bdist.linux-x86_64/egg/ludwig/models
# copying build/lib/ludwig/models/__init__.py -> build/bdist.linux-x86_64/egg/ludwig/models
# copying build/lib/ludwig/models/outputs.py -> build/bdist.linux-x86_64/egg/ludwig/models
# copying build/lib/ludwig/models/combiners.py -> build/bdist.linux-x86_64/egg/ludwig/models
# copying build/lib/ludwig/api.py -> build/bdist.linux-x86_64/egg/ludwig
# copying build/lib/ludwig/predict.py -> build/bdist.linux-x86_64/egg/ludwig
# copying build/lib/ludwig/test_performance.py -> build/bdist.linux-x86_64/egg/ludwig
# copying build/lib/ludwig/constants.py -> build/bdist.linux-x86_64/egg/ludwig
# copying build/lib/ludwig/visualize.py -> build/bdist.linux-x86_64/egg/ludwig
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/contribs/comet.py to comet.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/contribs/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/contribs/wandb.py to wandb.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/experiment.py to experiment.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/date_feature.py to date_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/timeseries_feature.py to timeseries_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/category_feature.py to category_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/text_feature.py to text_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/bag_feature.py to bag_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/binary_feature.py to binary_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/vector_feature.py to vector_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/base_feature.py to base_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/numerical_feature.py to numerical_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/h3_feature.py to h3_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/sequence_feature.py to sequence_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/set_feature.py to set_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/audio_feature.py to audio_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/feature_utils.py to feature_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/feature_registries.py to feature_registries.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/features/image_feature.py to image_feature.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/data/split_dataset.py to split_dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/data/preprocessing.py to preprocessing.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/data/dataset_synthesyzer.py to dataset_synthesyzer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/data/postprocessing.py to postprocessing.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/data/dataset.py to dataset.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/data/concatenate_datasets.py to concatenate_datasets.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/data/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/globals.py to globals.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/train.py to train.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/data_utils.py to data_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/image_utils.py to image_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/misc.py to misc.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/nlp_utils.py to nlp_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/batcher.py to batcher.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/html_utils.py to html_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/defaults.py to defaults.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/strings_utils.py to strings_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/h3_util.py to h3_util.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/algorithms_utils.py to algorithms_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/tf_utils.py to tf_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/visualization_utils.py to visualization_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/print_utils.py to print_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/audio_utils.py to audio_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/metrics_utils.py to metrics_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/math_utils.py to math_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/utils/time_utils.py to time_utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/neuropod_export.py to neuropod_export.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/cli.py to cli.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/contrib.py to contrib.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/collect.py to collect.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/serve.py to serve.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/model.py to model.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/sequence_decoders.py to sequence_decoders.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/reduction_modules.py to reduction_modules.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/embedding_modules.py to embedding_modules.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/measure_modules.py to measure_modules.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/fully_connected_modules.py to fully_connected_modules.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/image_encoders.py to image_encoders.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/dense_encoders.py to dense_encoders.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/loss_modules.py to loss_modules.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/sequence_encoders.py to sequence_encoders.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/initializer_modules.py to initializer_modules.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/recurrent_modules.py to recurrent_modules.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/optimization_modules.py to optimization_modules.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/h3_encoders.py to h3_encoders.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/attention_modules.py to attention_modules.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/date_encoders.py to date_encoders.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/modules/convolutional_modules.py to convolutional_modules.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/inputs.py to inputs.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/outputs.py to outputs.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/models/combiners.py to combiners.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/api.py to api.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/predict.py to predict.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/test_performance.py to test_performance.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/constants.py to constants.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ludwig/visualize.py to visualize.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying ludwig.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ludwig.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ludwig.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ludwig.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ludwig.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ludwig.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/ludwig-0.2.2.7-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing ludwig-0.2.2.7-py3.6.egg
# creating /usr/local/lib/python3.6/dist-packages/ludwig-0.2.2.7-py3.6.egg
# Extracting ludwig-0.2.2.7-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding ludwig 0.2.2.7 to easy-install.pth file
# Installing ludwig script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/ludwig-0.2.2.7-py3.6.egg
# Processing dependencies for ludwig==0.2.2.7
# Searching for absl-py==0.9.0
# Best match: absl-py 0.9.0
# Adding absl-py 0.9.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for PyYAML==3.13
# Best match: PyYAML 3.13
# Adding PyYAML 3.13 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tensorflow-gpu==1.15.2
# Best match: tensorflow-gpu 1.15.2
# Adding tensorflow-gpu 1.15.2 to easy-install.pth file
# Installing estimator_ckpt_converter script to /usr/local/bin
# Installing freeze_graph script to /usr/local/bin
# Installing saved_model_cli script to /usr/local/bin
# Installing tensorboard script to /usr/local/bin
# Installing tf_upgrade_v2 script to /usr/local/bin
# Installing tflite_convert script to /usr/local/bin
# Installing toco script to /usr/local/bin
# Installing toco_from_protos script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tqdm==4.41.1
# Best match: tqdm 4.41.1
# Adding tqdm 4.41.1 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for scikit-learn==0.22.2.post1
# Best match: scikit-learn 0.22.2.post1
# Adding scikit-learn 0.22.2.post1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tabulate==0.8.7
# Best match: tabulate 0.8.7
# Adding tabulate 0.8.7 to easy-install.pth file
# Installing tabulate script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for scipy==1.4.1
# Best match: scipy 1.4.1
# Adding scipy 1.4.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pandas==1.0.3
# Best match: pandas 1.0.3
# Adding pandas 1.0.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.18.4
# Best match: numpy 1.18.4
# Adding numpy 1.18.4 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for h5py==2.10.0
# Best match: h5py 2.10.0
# Adding h5py 2.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Cython==0.29.18
# Best match: Cython 0.29.18
# Adding Cython 0.29.18 to easy-install.pth file
# Installing cygdb script to /usr/local/bin
# Installing cython script to /usr/local/bin
# Installing cythonize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for six==1.12.0
# Best match: six 1.12.0
# Adding six 1.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for wheel==0.34.2
# Best match: wheel 0.34.2
# Adding wheel 0.34.2 to easy-install.pth file
# Installing wheel script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tensorflow-estimator==1.15.1
# Best match: tensorflow-estimator 1.15.1
# Adding tensorflow-estimator 1.15.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for termcolor==1.1.0
# Best match: termcolor 1.1.0
# Adding termcolor 1.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for grpcio==1.29.0
# Best match: grpcio 1.29.0
# Adding grpcio 1.29.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for astor==0.8.1
# Best match: astor 0.8.1
# Adding astor 0.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for wrapt==1.12.1
# Best match: wrapt 1.12.1
# Adding wrapt 1.12.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for gast==0.2.2
# Best match: gast 0.2.2
# Adding gast 0.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for protobuf==3.10.0
# Best match: protobuf 3.10.0
# Adding protobuf 3.10.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Keras-Preprocessing==1.1.2
# Best match: Keras-Preprocessing 1.1.2
# Adding Keras-Preprocessing 1.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for opt-einsum==3.2.1
# Best match: opt-einsum 3.2.1
# Adding opt-einsum 3.2.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for google-pasta==0.2.0
# Best match: google-pasta 0.2.0
# Adding google-pasta 0.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for tensorboard==1.15.0
# Best match: tensorboard 1.15.0
# Adding tensorboard 1.15.0 to easy-install.pth file
# Installing tensorboard script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Keras-Applications==1.0.8
# Best match: Keras-Applications 1.0.8
# Adding Keras-Applications 1.0.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for joblib==0.15.1
# Best match: joblib 0.15.1
# Adding joblib 0.15.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for python-dateutil==2.8.1
# Best match: python-dateutil 2.8.1
# Adding python-dateutil 2.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for pytz==2018.9
# Best match: pytz 2018.9
# Adding pytz 2018.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for setuptools==46.4.0
# Best match: setuptools 46.4.0
# Adding setuptools 46.4.0 to easy-install.pth file
# Installing easy_install script to /usr/local/bin
# Installing easy_install-3.8 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Werkzeug==1.0.1
# Best match: Werkzeug 1.0.1
# Adding Werkzeug 1.0.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for Markdown==3.2.2
# Best match: Markdown 3.2.2
# Adding Markdown 3.2.2 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for importlib-metadata==1.6.0
# Best match: importlib-metadata 1.6.0
# Adding importlib-metadata 1.6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for zipp==3.1.0
# Best match: zipp 3.1.0
# Adding zipp 3.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for ludwig==0.2.2.7
# ERROR: tensorflow 2.2.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 1.15.0 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorflow-estimator<2.3.0,>=2.2.0, but you'll have tensorflow-estimator 1.15.1 which is incompatible.
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# zip_safe flag not set; analyzing archive contents...
# ludwig.__pycache__.neuropod_export.cpython-36: module references __file__

# %% [markdown]
# ### Download the dataset

# %%
# !wget --header="Host: doc-08-a0-docs.googleusercontent.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://mail.google.com/mail/u/0/" --header="Cookie: AUTH_h2usbqe61t3p2javmc9f8vev3k7aj2re=09663297046543970124|1590855225000|vnbtokaapd9nf3iroaoqmb4dpinng0fa; AUTH_h2usbqe61t3p2javmc9f8vev3k7aj2re_nonce=jegbp49t4g4c6; NID=202=LrP4uDlw-tpJIrOsSSVGjEUAYFBvMgE7pYsHllDi2RvAiohnhILxLsaostbt-xc33InPBNV05z_jAtAw4Km239HIJCcIFMoWS8Yh1FmMW-xpd8qowQuNbmhfho6LYG4h7_JheMnumByEDYwFL3O_tCzX30sFKeeVfNE_XxYUTwM" --header="Connection: keep-alive" "https://doc-08-a0-docs.googleusercontent.com/docs/securesc/035r11cge54f61vkg6q5351jddbf1r9g/v4neda48nf159ukdu6sibi9d1aq1f1l8/1590855525000/09367493494736841528/09663297046543970124/15yNTXYb65oz43nn9PIu6kyp792rr_yZ5?e=download&authuser=0&nonce=jegbp49t4g4c6&user=09663297046543970124&hash=r0obp839dgutqnrohet7ej0oq9dhmcbg" -c -O 'Hi-En-Parallel_Corpus.xlsx'
# Out:
# --2020-05-30 16:20:08--  https://doc-08-a0-docs.googleusercontent.com/docs/securesc/035r11cge54f61vkg6q5351jddbf1r9g/v4neda48nf159ukdu6sibi9d1aq1f1l8/1590855525000/09367493494736841528/09663297046543970124/15yNTXYb65oz43nn9PIu6kyp792rr_yZ5?e=download&authuser=0&nonce=jegbp49t4g4c6&user=09663297046543970124&hash=r0obp839dgutqnrohet7ej0oq9dhmcbg
# Resolving doc-08-a0-docs.googleusercontent.com (doc-08-a0-docs.googleusercontent.com)... 64.233.189.132, 2404:6800:4008:c07::84
# Connecting to doc-08-a0-docs.googleusercontent.com (doc-08-a0-docs.googleusercontent.com)|64.233.189.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘Hi-En-Parallel_Corpus.xlsx’
#
# Hi-En-Parallel_Corp     [ <=>                ]  16.83M   101MB/s    in 0.2s
#
# 2020-05-30 16:20:08 (101 MB/s) - ‘Hi-En-Parallel_Corpus.xlsx’ saved [17653110]

# %%
# !ls
# Out:
# Hi-En-Parallel_Corpus.xlsx  ludwig  sample_data

# %% [markdown]
# ### Pre-process the dataset into csv file

# %%
# import libraries for processing
import pandas as pd
import numpy as np
import string
from string import digits
import matplotlib.pyplot as plt
# %matplotlib inline
import re
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.layers import Input, LSTM, Embedding, Dense
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
lines = pd.read_excel('Hi-En-Parallel_Corpus.xlsx')
lines.head()
# Out:
#                                     english_sentence                                     hindi_sentence
# 0  politicians do not have permission to do what ...  राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 1         I'd like to tell you about one such child,  मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 2  This percentage is even greater than the perce...   यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# 3  what we really mean is that they're bad at not...     हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते
# 4  .The ending portion of these Vedas is called U...        इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।

# %%
lines.english_sentence=lines.english_sentence.astype(str)
lines.hindi_sentence=lines.hindi_sentence.astype(str)
lines.head()
# Out:
#                                     english_sentence                                     hindi_sentence
# 0  politicians do not have permission to do what ...  राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 1         I'd like to tell you about one such child,  मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 2  This percentage is even greater than the perce...   यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# 3  what we really mean is that they're bad at not...     हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते
# 4  .The ending portion of these Vedas is called U...        इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।

# %%
lines.to_csv('translation.csv', index=None)

# %%
# !head translation.csv
# Out:
# english_sentence,hindi_sentence
# politicians do not have permission to do what needs to be done.,"राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह करने कि अनुमति नहीं है ."
# "I'd like to tell you about one such child,","मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहूंगी,"
# This percentage is even greater than the percentage in India.,यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# what we really mean is that they're bad at not paying attention.,हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते
# .The ending portion of these Vedas is called Upanishad.,इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।
# "The then Governor of Kashmir resisted transfer , but was finally reduced to subjection with the aid of British .","कश्मीर के तत्कालीन गवर्नर ने इस हस्तांतरण का विरोध किया था , लेकिन अंग्रेजों की सहायता से उनकी आवाज दबा दी गयी ."
# In this lies the circumstances of people before you.,इसमें तुमसे पूर्व गुज़रे हुए लोगों के हालात हैं।
# "And who are we to say, even, that they are wrong",और हम होते कौन हैं यह कहने भी वाले कि वे गलत हैं
# “”Global Warming“” refer to warming caused in recent decades and probability of its continual presence and its indirect effect on human being.,ग्लोबल वॉर्मिंग से आशय हाल ही के दशकों में हुई वार्मिंग और इसके निरंतर बने रहने के अनुमान और इसके अप्रत्यक्ष रूप से मानव पर पड़ने वाले प्रभाव से है।

# %% [markdown]
# ### Create model_definition_file.yaml specifying column name and model architecture with attention mechansim

# %%
# %%writefile model_definition_file.yaml
# input_features:
#     -
#         name: english_sentence
#         type: text
#         level: word
#         encoder: rnn
#         cell_type: lstm
#         reduce_output: null
#         preprocessing:
#           word_format: english_tokenize
#
# output_features:
#     -
#         name: hindi_sentence
#         type: text
#         level: word
#         decoder: generator
#         cell_type: lstm
#         attention: bahdanau
#         loss:
#             type: sampled_softmax_cross_entropy
#         preprocessing:
#           word_format: hindi_tokenize
#
# training:
#     batch_size: 96
#     epochs: 8
# Out:
# Writing model_definition_file.yaml

# %% [markdown]
# ### Check GPU is available

# %%
# !nvidia-smi
# Out:
# Sat May 30 16:30:26 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Train the model

# %%
# !ludwig experiment \
  --data_csv translation.csv \
  --model_definition_file model_definition_file.yaml
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ███████████████████████
# █ █ █ █  ▜█ █ █ █ █   █
# █ █ █ █ █ █ █ █ █ █ ███
# █ █   █ █ █ █ █ █ █ ▌ █
# █ █████ █ █ █ █ █ █ █ █
# █     █  ▟█     █ █   █
# ███████████████████████
# ludwig v0.2.2.7 - Experiment
#
# Experiment name: experiment
# Model name: run
# Output path: results/experiment_run
#
#
# ludwig_version: '0.2.2.7'
# command: ('/usr/local/bin/ludwig experiment --data_csv translation.csv '
#  '--model_definition_file model_definition_file.yaml')
# random_seed: 42
# input_data: 'translation.csv'
# model_definition: {   'combiner': {'type': 'concat'},
#     'input_features': [   {   'cell_type': 'lstm',
#                               'encoder': 'rnn',
#                               'level': 'word',
#                               'name': 'english_sentence',
#                               'preprocessing': {   'word_format': 'english_tokenize'},
#                               'reduce_output': None,
#                               'tied_weights': None,
#                               'type': 'text'}],
#     'output_features': [   {   'attention': 'bahdanau',
#                                'cell_type': 'lstm',
#                                'decoder': 'generator',
#                                'dependencies': [],
#                                'level': 'word',
#                                'loss': {   'class_similarities_temperature': 0,
#                                            'class_weights': 1,
#                                            'confidence_penalty': 0,
#                                            'distortion': 0.75,
#                                            'labels_smoothing': 0,
#                                            'negative_samples': 25,
#                                            'robust_lambda': 0,
#                                            'sampler': 'log_uniform',
#                                            'type': 'sampled_softmax_cross_entropy',
#                                            'unique': False,
#                                            'weight': 1},
#                                'name': 'hindi_sentence',
#                                'preprocessing': {   'word_format': 'hindi_tokenize'},
#                                'reduce_dependencies': 'sum',
#                                'reduce_input': 'sum',
#                                'type': 'text'}],
#     'preprocessing': {   'audio': {   'audio_feature': {'type': 'raw'},
#                                       'audio_file_length_limit_in_s': 7.5,
#                                       'in_memory': True,
#                                       'missing_value_strategy': 'backfill',
#                                       'norm': None,
#                                       'padding_value': 0},
#                          'bag': {   'fill_value': '<UNK>',
#                                     'lowercase': False,
#                                     'missing_value_strategy': 'fill_with_const',
#                                     'most_common': 10000,
#                                     'tokenizer': 'space'},
#                          'binary': {   'fill_value': 0,
#                                        'missing_value_strategy': 'fill_with_const'},
#                          'category': {   'fill_value': '<UNK>',
#                                          'lowercase': False,
#                                          'missing_value_strategy': 'fill_with_const',
#                                          'most_common': 10000},
#                          'date': {   'datetime_format': None,
#                                      'fill_value': '',
#                                      'missing_value_strategy': 'fill_with_const'},
#                          'force_split': False,
#                          'h3': {   'fill_value': 576495936675512319,
#                                    'missing_value_strategy': 'fill_with_const'},
#                          'image': {   'in_memory': True,
#                                       'missing_value_strategy': 'backfill',
#                                       'num_processes': 1,
#                                       'resize_method': 'interpolate',
#                                       'scaling': 'pixel_normalization'},
#                          'numerical': {   'fill_value': 0,
#                                           'missing_value_strategy': 'fill_with_const',
#                                           'normalization': None},
#                          'sequence': {   'fill_value': '<UNK>',
#                                          'lowercase': False,
#                                          'missing_value_strategy': 'fill_with_const',
#                                          'most_common': 20000,
#                                          'padding': 'right',
#                                          'padding_symbol': '<PAD>',
#                                          'sequence_length_limit': 256,
#                                          'tokenizer': 'space',
#                                          'unknown_symbol': '<UNK>',
#                                          'vocab_file': None},
#                          'set': {   'fill_value': '<UNK>',
#                                     'lowercase': False,
#                                     'missing_value_strategy': 'fill_with_const',
#                                     'most_common': 10000,
#                                     'tokenizer': 'space'},
#                          'split_probabilities': (0.7, 0.1, 0.2),
#                          'stratify': None,
#                          'text': {   'char_most_common': 70,
#                                      'char_sequence_length_limit': 1024,
#                                      'char_tokenizer': 'characters',
#                                      'char_vocab_file': None,
#                                      'fill_value': '<UNK>',
#                                      'lowercase': True,
#                                      'missing_value_strategy': 'fill_with_const',
#                                      'padding': 'right',
#                                      'padding_symbol': '<PAD>',
#                                      'unknown_symbol': '<UNK>',
#                                      'word_most_common': 20000,
#                                      'word_sequence_length_limit': 256,
#                                      'word_tokenizer': 'space_punct',
#                                      'word_vocab_file': None},
#                          'timeseries': {   'fill_value': '',
#                                            'missing_value_strategy': 'fill_with_const',
#                                            'padding': 'right',
#                                            'padding_value': 0,
#                                            'timeseries_length_limit': 256,
#                                            'tokenizer': 'space'},
#                          'vector': {   'fill_value': '',
#                                        'missing_value_strategy': 'fill_with_const'}},
#     'training': {   'batch_size': 96,
#                     'bucketing_field': None,
#                     'decay': False,
#                     'decay_rate': 0.96,
#                     'decay_steps': 10000,
#                     'dropout_rate': 0.0,
#                     'early_stop': 5,
#                     'epochs': 8,
#                     'eval_batch_size': 0,
#                     'gradient_clipping': None,
#                     'increase_batch_size_on_plateau': 0,
#                     'increase_batch_size_on_plateau_max': 512,
#                     'increase_batch_size_on_plateau_patience': 5,
#                     'increase_batch_size_on_plateau_rate': 2,
#                     'learning_rate': 0.001,
#                     'learning_rate_warmup_epochs': 1,
#                     'optimizer': {   'beta1': 0.9,
#                                      'beta2': 0.999,
#                                      'epsilon': 1e-08,
#                                      'type': 'adam'},
#                     'reduce_learning_rate_on_plateau': 0,
#                     'reduce_learning_rate_on_plateau_patience': 5,
#                     'reduce_learning_rate_on_plateau_rate': 0.5,
#                     'regularization_lambda': 0,
#                     'regularizer': 'l2',
#                     'staircase': False,
#                     'validation_field': 'combined',
#                     'validation_measure': 'loss'}}
#
#
# Using full raw csv, no hdf5 and json file with the same name have been found
# Building dataset (it may take a while)
# Writing dataset
# Writing train set metadata with vocabulary
# Training set: 89449
# Validation set: 12709
# Test set: 25449
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ludwig-0.2.2.7-py3.6.egg/ludwig/models/modules/recurrent_modules.py:204: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ludwig-0.2.2.7-py3.6.egg/ludwig/models/modules/recurrent_modules.py:207: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ludwig-0.2.2.7-py3.6.egg/ludwig/models/modules/recurrent_modules.py:212: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ludwig-0.2.2.7-py3.6.egg/ludwig/models/modules/recurrent_modules.py:215: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ludwig-0.2.2.7-py3.6.egg/ludwig/models/modules/loss_modules.py:275: The name tf.nn.log_uniform_candidate_sampler is deprecated. Please use tf.random.log_uniform_candidate_sampler instead.
#
#
# ╒══════════╕
# │ TRAINING │
# ╘══════════╛
#
# 2020-06-01 17:44:19.923666: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-06-01 17:44:19.927866: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-06-01 17:44:19.928075: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x8f8fa40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-01 17:44:19.928107: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-06-01 17:44:19.930055: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-01 17:44:20.068469: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-01 17:44:20.069186: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x8f8f880 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-06-01 17:44:20.069216: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-06-01 17:44:20.070392: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-01 17:44:20.070892: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-06-01 17:44:20.084214: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-06-01 17:44:20.296832: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-06-01 17:44:20.390386: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-06-01 17:44:20.410719: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-06-01 17:44:20.649767: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-06-01 17:44:20.774329: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-06-01 17:44:21.276951: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-01 17:44:21.277194: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-01 17:44:21.277860: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-01 17:44:21.278360: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-06-01 17:44:21.278496: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-06-01 17:44:21.279775: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-06-01 17:44:21.279808: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-06-01 17:44:21.279818: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-06-01 17:44:21.279937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-01 17:44:21.280485: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-01 17:44:21.280992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
#
# Epoch 1
# Training:   0% 0/932 [00:00<?, ?it/s]2020-06-01 17:44:22.800618: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# Training: 100% 932/932 [05:12<00:00,  2.98it/s]
# Evaluation train: 100% 932/932 [14:45<00:00,  1.05it/s]
# Evaluation vali : 100% 133/133 [02:06<00:00,  1.05it/s]
# Evaluation test : 100% 266/266 [04:11<00:00,  1.06it/s]
# Took 26m 16.4375s
# ╒══════════════════╤════════╤════════════╤══════════════════╤═════════════════╤══════════════╤═════════════════╕
# │ hindi_sentence   │   loss │   accuracy │   token_accuracy │   last_accuracy │   perplexity │   edit_distance │
# ╞══════════════════╪════════╪════════════╪══════════════════╪═════════════════╪══════════════╪═════════════════╡
# │ training         │ 5.1767 │     0.0000 │           0.0440 │          0.0248 │       5.1767 │          8.1346 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ vali             │ 5.1807 │     0.0000 │           0.0443 │          0.0254 │       5.1807 │          8.1158 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ test             │ 5.1849 │     0.0000 │           0.0444 │          0.0240 │       5.1849 │          8.1951 │
# ╘══════════════════╧════════╧════════════╧══════════════════╧═════════════════╧══════════════╧═════════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 2
# Training: 100% 932/932 [05:12<00:00,  2.98it/s]
# Evaluation train: 100% 932/932 [13:56<00:00,  1.11it/s]
# Evaluation vali : 100% 133/133 [01:59<00:00,  1.11it/s]
# Evaluation test : 100% 266/266 [03:56<00:00,  1.12it/s]
# Took 25m 5.4913s
# ╒══════════════════╤════════╤════════════╤══════════════════╤═════════════════╤══════════════╤═════════════════╕
# │ hindi_sentence   │   loss │   accuracy │   token_accuracy │   last_accuracy │   perplexity │   edit_distance │
# ╞══════════════════╪════════╪════════════╪══════════════════╪═════════════════╪══════════════╪═════════════════╡
# │ training         │ 4.2812 │     0.0000 │           0.0682 │          0.0248 │       4.2812 │          0.8582 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ vali             │ 4.2872 │     0.0000 │           0.0683 │          0.0254 │       4.2872 │          0.8589 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ test             │ 4.2943 │     0.0000 │           0.0681 │          0.0239 │       4.2943 │          0.8596 │
# ╘══════════════════╧════════╧════════════╧══════════════════╧═════════════════╧══════════════╧═════════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 3
# Training: 100% 932/932 [05:11<00:00,  3.00it/s]
# Evaluation train: 100% 932/932 [14:15<00:00,  1.09it/s]
# Evaluation vali : 100% 133/133 [02:02<00:00,  1.09it/s]
# Evaluation test : 100% 266/266 [04:02<00:00,  1.10it/s]
# Took 25m 30.9834s
# ╒══════════════════╤════════╤════════════╤══════════════════╤═════════════════╤══════════════╤═════════════════╕
# │ hindi_sentence   │   loss │   accuracy │   token_accuracy │   last_accuracy │   perplexity │   edit_distance │
# ╞══════════════════╪════════╪════════════╪══════════════════╪═════════════════╪══════════════╪═════════════════╡
# │ training         │ 4.0537 │     0.0000 │           0.0493 │          0.2096 │       4.0537 │          0.9508 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ vali             │ 4.0635 │     0.0000 │           0.0492 │          0.2117 │       4.0635 │          0.9544 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ test             │ 4.0722 │     0.0000 │           0.0489 │          0.2100 │       4.0722 │          0.9561 │
# ╘══════════════════╧════════╧════════════╧══════════════════╧═════════════════╧══════════════╧═════════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 4
# Training: 100% 932/932 [05:09<00:00,  3.02it/s]
# Evaluation train: 100% 932/932 [14:40<00:00,  1.06it/s]
# Evaluation vali : 100% 133/133 [02:04<00:00,  1.07it/s]
# Evaluation test : 100% 266/266 [04:10<00:00,  1.06it/s]
# Took 26m 3.8589s
# ╒══════════════════╤════════╤════════════╤══════════════════╤═════════════════╤══════════════╤═════════════════╕
# │ hindi_sentence   │   loss │   accuracy │   token_accuracy │   last_accuracy │   perplexity │   edit_distance │
# ╞══════════════════╪════════╪════════════╪══════════════════╪═════════════════╪══════════════╪═════════════════╡
# │ training         │ 3.8342 │     0.0000 │           0.0699 │          0.3755 │       3.8342 │          1.0466 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ vali             │ 3.8490 │     0.0000 │           0.0697 │          0.3702 │       3.8490 │          1.0522 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ test             │ 3.8577 │     0.0000 │           0.0697 │          0.3650 │       3.8577 │          1.0566 │
# ╘══════════════════╧════════╧════════════╧══════════════════╧═════════════════╧══════════════╧═════════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 5
# Training: 100% 932/932 [05:07<00:00,  3.03it/s]
# Evaluation train: 100% 932/932 [14:42<00:00,  1.06it/s]
# Evaluation vali : 100% 133/133 [02:06<00:00,  1.05it/s]
# Evaluation test : 100% 266/266 [04:11<00:00,  1.06it/s]
# Took 26m 8.2983s
# ╒══════════════════╤════════╤════════════╤══════════════════╤═════════════════╤══════════════╤═════════════════╕
# │ hindi_sentence   │   loss │   accuracy │   token_accuracy │   last_accuracy │   perplexity │   edit_distance │
# ╞══════════════════╪════════╪════════════╪══════════════════╪═════════════════╪══════════════╪═════════════════╡
# │ training         │ 3.6821 │     0.0000 │           0.0706 │          0.3654 │       3.6821 │          1.0412 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ vali             │ 3.7057 │     0.0000 │           0.0698 │          0.3586 │       3.7057 │          1.0523 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ test             │ 3.7140 │     0.0000 │           0.0695 │          0.3587 │       3.7140 │          1.0509 │
# ╘══════════════════╧════════╧════════════╧══════════════════╧═════════════════╧══════════════╧═════════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 6
# Training: 100% 932/932 [05:09<00:00,  3.01it/s]
# Evaluation train: 100% 932/932 [14:38<00:00,  1.06it/s]
# Evaluation vali : 100% 133/133 [02:04<00:00,  1.06it/s]
# Evaluation test : 100% 266/266 [04:09<00:00,  1.07it/s]
# Took 26m 2.5815s
# ╒══════════════════╤════════╤════════════╤══════════════════╤═════════════════╤══════════════╤═════════════════╕
# │ hindi_sentence   │   loss │   accuracy │   token_accuracy │   last_accuracy │   perplexity │   edit_distance │
# ╞══════════════════╪════════╪════════════╪══════════════════╪═════════════════╪══════════════╪═════════════════╡
# │ training         │ 3.5077 │     0.0000 │           0.0675 │          0.3837 │       3.5077 │          1.0122 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ vali             │ 3.5398 │     0.0000 │           0.0666 │          0.3763 │       3.5398 │          1.0192 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ test             │ 3.5487 │     0.0000 │           0.0665 │          0.3764 │       3.5487 │          1.0261 │
# ╘══════════════════╧════════╧════════════╧══════════════════╧═════════════════╧══════════════╧═════════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 7
# Training: 100% 932/932 [05:08<00:00,  3.02it/s]
# Evaluation train: 100% 932/932 [13:53<00:00,  1.12it/s]
# Evaluation vali : 100% 133/133 [01:59<00:00,  1.11it/s]
# Evaluation test : 100% 266/266 [03:56<00:00,  1.12it/s]
# Took 24m 57.7614s
# ╒══════════════════╤════════╤════════════╤══════════════════╤═════════════════╤══════════════╤═════════════════╕
# │ hindi_sentence   │   loss │   accuracy │   token_accuracy │   last_accuracy │   perplexity │   edit_distance │
# ╞══════════════════╪════════╪════════════╪══════════════════╪═════════════════╪══════════════╪═════════════════╡
# │ training         │ 3.4108 │     0.0002 │           0.0688 │          0.3171 │       3.4108 │          0.8260 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ vali             │ 3.4538 │     0.0000 │           0.0670 │          0.3062 │       3.4538 │          0.8392 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ test             │ 3.4607 │     0.0002 │           0.0674 │          0.3111 │       3.4607 │          0.8378 │
# ╘══════════════════╧════════╧════════════╧══════════════════╧═════════════════╧══════════════╧═════════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch 8
# Training: 100% 932/932 [05:04<00:00,  3.06it/s]
# Evaluation train: 100% 932/932 [14:35<00:00,  1.06it/s]
# Evaluation vali : 100% 133/133 [02:04<00:00,  1.07it/s]
# Evaluation test : 100% 266/266 [04:08<00:00,  1.07it/s]
# Took 25m 52.7236s
# ╒══════════════════╤════════╤════════════╤══════════════════╤═════════════════╤══════════════╤═════════════════╕
# │ hindi_sentence   │   loss │   accuracy │   token_accuracy │   last_accuracy │   perplexity │   edit_distance │
# ╞══════════════════╪════════╪════════════╪══════════════════╪═════════════════╪══════════════╪═════════════════╡
# │ training         │ 3.2690 │     0.0001 │           0.0698 │          0.4199 │       3.2690 │          0.9758 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ vali             │ 3.3247 │     0.0000 │           0.0676 │          0.4137 │       3.3247 │          0.9853 │
# ├──────────────────┼────────┼────────────┼──────────────────┼─────────────────┼──────────────┼─────────────────┤
# │ test             │ 3.3300 │     0.0000 │           0.0676 │          0.4073 │       3.3300 │          0.9921 │
# ╘══════════════════╧════════╧════════════╧══════════════════╧═════════════════╧══════════════╧═════════════════╛
# Validation loss on combined improved, model saved
#
# Best validation model epoch: 8
# Best validation model loss on validation set combined: 3.324721759361215
# Best validation model loss on test set combined: 3.3299767950147094
#
# Finished: experiment_run
# Saved to: results/experiment_run
#
# ╒═════════╕
# │ PREDICT │
# ╘═════════╛
#
# Evaluation: 100% 266/266 [04:08<00:00,  1.07it/s]
# tcmalloc: large alloc 1586429952 bytes == 0x49270000 @  0x7f0e97d83001 0x7f0e93f67765 0x7f0e93fcbbb0 0x7f0e93fcda4f 0x7f0e94064048 0x50a635 0x50cd96 0x509758 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509042 0x594931 0x549e5f 0x5513d1 0x5a9cbc 0x50a5c3 0x50cd96 0x509758 0x50a48d 0x50bfb4 0x509758 0x50a48d
# tcmalloc: large alloc 1586429952 bytes == 0xa7b60000 @  0x7f0e97d811e7 0x7f0e93f675e1 0x7f0e93fce420 0x7f0e93fc37d5 0x7f0e94066934 0x50a635 0x50cd96 0x507d64 0x588d41 0x59fc4e 0x7f0e93fb74ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509042 0x594931 0x549e5f 0x5513d1 0x5a9cbc 0x50a5c3 0x50cd96 0x509758 0x50a48d
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# ===== hindi_sentence =====
# accuracy: 3.929427482415812e-05
# edit_distance: 0.9920619524618072
# last_accuracy: 0.40728515855239894
# loss: 3.329976799811374
# overall_stats: { 'avg_f1_score_macro': 0.007575626418797641,
#   'avg_f1_score_micro': 0.407285158552399,
#   'avg_f1_score_weighted': 0.302557409289198,
#   'avg_precision_macro': 0.012153860580827744,
#   'avg_precision_micro': 0.40728515855239894,
#   'avg_precision_weighted': 0.40728515855239894,
#   'avg_recall_macro': 0.008061388708459334,
#   'avg_recall_micro': 0.40728515855239894,
#   'avg_recall_weighted': 0.40728515855239894,
#   'kappa_score': 0.17676433684187132,
#   'token_accuracy': 0.40728515855239894}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Streaming output truncated to the last 5000 lines.
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   nauksaana: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   phumcaato: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   561: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   एरत: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   lम: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   सडबर: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   नमयत: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   अधरवक: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   गढन: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   लसह: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   sql: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   argentina: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   रयद: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   आशनऋ: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   189: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   sakara: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   apnaayaom: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   raoga: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   aagaat: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   sambaavanaaaaom: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   लककल: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   frubber: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   भटल: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   समवय: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   लभन: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   ऑइड: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   अवइलब: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   zसकत: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
# ...
#   zzz: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   यतऋर: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   यएनव: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   रजस: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   173: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   3छ: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   zइफ: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   इरत: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   1207: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   dr: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   strangelove: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   stickers: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   stencils: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   chalk: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   2870: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   छडन: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   फऋश: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   टपकन: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   उभयज: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   औरच: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   slide: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   982: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   985: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
#     'sensitivity': 0,
#     'specificity': 1.0,
#     'true_negative_rate': 1.0,
#     'true_negatives': 25449,
#     'true_positive_rate': 0,
#     'true_positives': 0},
#   saaibat: {   'accuracy': 1.0,
#     'f1_score': 0,
#     'fall_out': 0.0,
#     'false_discovery_rate': 1.0,
#     'false_negative_rate': 1.0,
#     'false_negatives': 0,
#     'false_omission_rate': 0.0,
#     'false_positive_rate': 0.0,
#     'false_positives': 0,
#     'hit_rate': 0,
#     'informedness': 0.0,
#     'markedness': 0.0,
#     'matthews_correlation_coefficient': 0,
#     'miss_rate': 1.0,
#     'negative_predictive_value': 1.0,
#     'positive_predictive_value': 0,
#     'precision': 0,
#     'recall': 0,
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# perplexity: 3.329976799811374
# token_accuracy: 0.06756778391330276
#
# Finished: experiment_run
# Saved to: results/experiment_run

# %%
# !ls
# Out:
# Hi-En-Parallel_Corpus.xlsx  results	     translation.hdf5
# ludwig			    sample_data      translation.json
# model_definition_file.yaml  translation.csv

# %% [markdown]
# ### Predicting Sample Sentence, specify model path and csv file

# %%
# !ludwig predict --data_csv translation.csv --model_path results/experiment_run/model
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ███████████████████████
# █ █ █ █  ▜█ █ █ █ █   █
# █ █ █ █ █ █ █ █ █ █ ███
# █ █   █ █ █ █ █ █ █ ▌ █
# █ █████ █ █ █ █ █ █ █ █
# █     █  ▟█     █ █   █
# ███████████████████████
# ludwig v0.2.2.7 - Predict
#
# Dataset path: translation.csv
# Model path: results/experiment_run/model
#
# Found hdf5 with the same filename of the csv, using it instead
# Loading metadata from: results/experiment_run/model/train_set_metadata.json
# Loading data from: translation.hdf5
#
# ╒═══════════════╕
# │ LOADING MODEL │
# ╘═══════════════╛
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ludwig-0.2.2.7-py3.6.egg/ludwig/models/modules/recurrent_modules.py:204: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ludwig-0.2.2.7-py3.6.egg/ludwig/models/modules/recurrent_modules.py:207: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ludwig-0.2.2.7-py3.6.egg/ludwig/models/modules/recurrent_modules.py:212: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ludwig-0.2.2.7-py3.6.egg/ludwig/models/modules/recurrent_modules.py:215: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/ludwig-0.2.2.7-py3.6.egg/ludwig/models/modules/loss_modules.py:275: The name tf.nn.log_uniform_candidate_sampler is deprecated. Please use tf.random.log_uniform_candidate_sampler instead.
#
# 2020-06-01 21:17:15.438973: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-06-01 21:17:15.443331: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-06-01 21:17:15.443736: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1770f40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-06-01 21:17:15.443770: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-06-01 21:17:15.446986: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-06-01 21:17:15.540975: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-01 21:17:15.541851: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1770840 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-06-01 21:17:15.541887: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-06-01 21:17:15.542118: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-01 21:17:15.542687: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-06-01 21:17:15.546553: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-06-01 21:17:15.553864: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-06-01 21:17:15.557590: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-06-01 21:17:15.566995: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-06-01 21:17:15.579088: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-06-01 21:17:15.586403: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-06-01 21:17:15.614008: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-06-01 21:17:15.614171: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-01 21:17:15.614801: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-01 21:17:15.615405: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2020-06-01 21:17:15.615507: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-06-01 21:17:15.616811: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-06-01 21:17:15.616842: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2020-06-01 21:17:15.616855: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2020-06-01 21:17:15.616986: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-01 21:17:15.617608: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-06-01 21:17:15.618247: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
#
# ╒═════════╕
# │ PREDICT │
# ╘═════════╛
#
# Evaluation:   0% 0/199 [00:00<?, ?it/s]2020-06-01 21:17:23.183519: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# Evaluation: 100% 199/199 [02:37<00:00,  1.26it/s]
# Saved to: results_0
